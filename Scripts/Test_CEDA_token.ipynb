# %%
import subprocess
import os

# %%
# Set your token here
TOKEN = "eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICI4ZjhmaUpyaUtDY3hmaHhzdU5vazVEekdJdFZ4amhhTWNJa05ZX2U4MnhJIn0.....hDqx31Mf3iq0vSH9bYUCgJz8EAjE9wJye3WbRxwMVt51VC3-N--dLMotdFT0-SkUXG8pHDVRXL-44etmGzqeNYLejcVtphiy0R38a1KnCtFT1Oums-Q-r-v9RRAtWUejcG8KCsekpxvWt63GlY8Ba7VO4eIt0_C-illyIIcwLeRLOk7c-53vwOYiT70NosYnibbrLtTi02oJTyNHuFW7w2-8I2JrFmG36HhJZqhOc_rjYLxvtG9mSAgoXTpHTO6srUJnz6gEd-eSyEFf97eZInE1uz_w2dmF0xNSNKQl2_6L5AVmbld7Fbpgfh3ZO2wOyN7tHwhWRAk4BPRbi5Qw5g"  # Replace with your actual token

# Test URL
TEST_URL = "https://dap.ceda.ac.uk/badc/ARCHIVE_INFO/ACCESS_TEST/RESTRICTED/TOKEN_CHECK"

# %%
# Command to test token access
command = [
    "wget",
    "-O", "-",  # Output result to stdout
    "-q",  # Quiet mode
    "--header", f"Authorization: Bearer {TOKEN}",
    TEST_URL
]

try:
    result = subprocess.run(command, check=True, capture_output=True, text=True)
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("Token authentication failed! Check your token and try again.")
    print(e.stderr)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>Login</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#
#
#
#
#         <!-- Bootstrap Core
#         CSS -->
#         <link rel="stylesheet" href="https://artefacts.ceda.ac.uk/themes/orgtheme_ceda_serv/0.2/4/flatly/bootstrap.css" media="screen">
#         <!-- Custom CSS -->
#         <link rel="stylesheet" href="https://artefacts.ceda.ac.uk/themes/orgtheme_ceda_serv/0.2/_assets/css/custom.min.css">
#         <link rel="stylesheet" href="https://artefacts.ceda.ac.uk/themes/orgtheme_ceda_serv/0.2/_assets/css/org-custom.css">
#
#
#
#
#         <link href="/static/fwtheme_django/css/fw-custom.css" rel="stylesheet">
#         <!-- Custom Fonts -->
# ...
